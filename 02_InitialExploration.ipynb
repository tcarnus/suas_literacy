# %% [markdown]
# <div style="float:right"><img src='files/assets/img/Suas_Logo_Header.png'></img></div>
#
# ## Suas Educational Development - Literacy Intervention Investigation
#
# # 02 Initial Exploration
#
# Contact: Adelaide Nic Chartaigh [adelaide@suas.ie]("mailto:adelaide@suas.ie")
# Author: Jonathan Sedar [jon.sedar@applied.ai]("mailto:jon.sedar@applied.ai")
# Date: Spring / Summer 2014
#
# #Contents
#
# + [Setup](#Setup)
# + [Import Data](#Import-Data)
# + [Visualisation and Single Feature Regression](#Visualisation-and-Single-Feature-Regression)

# %% [markdown]
# # Setup

# %%
## Interactive magics
# %matplotlib inline
# %qtconsole --colors=linux --ConsoleWidget.font_size=10 --ConsoleWidget.font_family='Consolas'

# %%
## Libraries and global options
from __future__ import division, print_function
import os
import sys
import re
import string

import pandas as pd
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
from matplotlib import cm
import sqlite3
from sklearn import linear_model
import pymc as pm

#from sklearn.covariance import MinCovDet
#from sklearn.preprocessing import Normalizer
#from collections import OrderedDict

# Set some default pandas and plotting formatting
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 1000)
pd.set_option('display.width', 1000)
pd.set_option('display.mpl_style', 'default')
pd.set_option('display.notebook_repr_html', True)
pd.set_option('display.expand_frame_repr', True)
pd.set_option('display.precision', 5)
pd.set_option('display.max_colwidth', 50)

plt.rcParams['figure.figsize'] = 6, 6

# handle temporary deprecation warning in pandas for describe()
import warnings
warnings.simplefilter("ignore", DeprecationWarning)
warnings.simplefilter("ignore", UserWarning)
warnings.simplefilter("ignore", FutureWarning)
warnings.simplefilter("ignore", RuntimeWarning)

remove_punct_map = dict.fromkeys(map(ord, string.punctuation))
# Out:
# Warning: statsmodels and/or patsy not found, not importing glm submodule.

# %% [markdown]
# # Import Data

# %%
## Read cleaned dataset back from db
cnx_sql3 = sqlite3.connect('data/SUAS_data_master_v001_tcc_cleaned.db')
cnx_sql3.text_factory = str
df = pd.read_sql('select * from df_piv', cnx_sql3, index_col=['code','schoolid','gender','test','testtype']
                 , parse_dates=['date_pre','date_post'])
cnx_sql3.close()

print(df.shape)
df.head()
# Out:
# (235, 8)
#                                                                date_pre  date_post  age_pre  age_post  raw_score_pre  raw_score_post  staard_score_pre  staard_score_post
# code         schoolid  gender test    testtype
# NDMS_ARAWm01 NDMS_ARAW m      reading acceleread_accelewrite 2013-10-21 2013-11-29     9.22      9.33             27              31                85                 89
# NDMS_ARAWm02 NDMS_ARAW m      reading acceleread_accelewrite 2013-10-21 2013-11-29     9.98     10.08             37              40                97                 94
# NDMS_ARAWm03 NDMS_ARAW m      reading acceleread_accelewrite 2013-10-21 2013-11-29    10.05     10.16             27              26                80                 76
# NDMS_ARAWm04 NDMS_ARAW m      reading acceleread_accelewrite 2013-10-21 2013-11-29    10.16     10.26             34              36                91                 89
# NDMS_ARAWm05 NDMS_ARAW m      reading acceleread_accelewrite 2013-10-21 2013-11-29    10.30     10.41             22              25                71                 74

# %% [markdown]
# ### Calc some deltas for convenience

# %%
df['date_delta'] = df['date_post'] - df['date_pre']
df['age_delta'] = df['age_post'] - df['age_pre']
df['raw_score_delta'] = df['raw_score_post'] - df['raw_score_pre']
df['staard_score_delta'] = df['staard_score_post'] - df['staard_score_pre']

df = df.sort_index(axis=1)
df.head()
# Out:
#                                                               age_delta  age_post  age_pre  date_delta  date_post   date_pre  raw_score_delta  raw_score_post  raw_score_pre  staard_score_delta  staard_score_post  staard_score_pre
# code         schoolid  gender test    testtype
# NDMS_ARAWm01 NDMS_ARAW m      reading acceleread_accelewrite       0.11      9.33     9.22     39 days 2013-11-29 2013-10-21                4              31             27                   4                 89                85
# NDMS_ARAWm02 NDMS_ARAW m      reading acceleread_accelewrite       0.10     10.08     9.98     39 days 2013-11-29 2013-10-21                3              40             37                  -3                 94                97
# NDMS_ARAWm03 NDMS_ARAW m      reading acceleread_accelewrite       0.11     10.16    10.05     39 days 2013-11-29 2013-10-21               -1              26             27                  -4                 76                80
# NDMS_ARAWm04 NDMS_ARAW m      reading acceleread_accelewrite       0.10     10.26    10.16     39 days 2013-11-29 2013-10-21                2              36             34                  -2                 89                91
# NDMS_ARAWm05 NDMS_ARAW m      reading acceleread_accelewrite       0.11     10.41    10.30     39 days 2013-11-29 2013-10-21                3              25             22                   3                 74                71

# %% [markdown]
# # Visualisation and Single Feature Regression

# %%
## scores pre vs post for all

x = df['staard_score_pre']
y = df['staard_score_post']

cm_cmap = cm.get_cmap('hsv')
fig, axes1d = plt.subplots(nrows=1, ncols=1, sharex=True, figsize=(12,6))
fig.subplots_adjust(wspace=0.2)
fig.suptitle('Correlation of pre-test and post-test scores')

sp = axes1d
clr = cm_cmap(0)
sp.scatter(x=x,y=y,color=clr,alpha=0.5,edgecolor='#999999')

# fit and plot a new linear model
regr = linear_model.LinearRegression()
regr.fit(pd.DataFrame(x),pd.DataFrame(y))
x_prime = np.linspace(x.min(),x.max(),num=10)[:,np.newaxis]
y_hat = regr.predict(x_prime)
sp.plot(x_prime,y_hat,linewidth=2,linestyle='dashed',color='green',alpha=0.8)

ss_res = regr.residues_[0]
ss_tot = np.sum((y - np.mean(y))**2)
rsq = 1 - (ss_res/ss_tot)

sp.annotate('R^2:  {:.2f}\nCoef: {:.2f}\nIntr: {:.2f}'.format(rsq,regr.coef_[0][0],regr.intercept_[0])
                ,xy=(1,0),xycoords='axes fraction'
                ,xytext=(-12,6),textcoords='offset points',color='green',weight='bold'
                ,size=12,ha='right',va='bottom')
sp.set_ylabel('Post-test Score')
sp.set_xlabel('Pre-test Score')
sp.axes.grid(True,linestyle='-',color='lightgrey')

plt.subplots_adjust(top=0.85)
plt.show()

# %%
## scores pre vs post for test type

## TODO

# %% [markdown]
# ---

# %% [markdown]
# # Bayesian Regression

# %% [markdown]
# ## Unpooled approach
# ... for comparison with Frequentist

# %%
## try unpooled model first for all

x = df['staard_score_pre']
y = df['staard_score_post']

with pm.Model() as individual_model:

    # priors for intercept, slope and precision - all uninformative
    alpha = pm.Normal('alpha', mu=0, sd=100**2)
    beta = pm.Normal('beta', mu=0, sd=100**2)
    sigma = pm.Uniform('sigma', lower=0, upper=100)

    # Linear model
    y_est = alpha + beta * x

    # Data likelihood
    likelihood = pm.Normal('event like', mu=y_est, sd=sigma, observed=y)

    # keep trace
    traces = pm.sample(5000, step=pm.NUTS(), start=pm.find_MAP(), progressbar=True)

    pm.traceplot(traces)
# Out:
#  [                  1%                  ] 54 of 5000 complete in 0.5 sec
#  [                  2%                  ] 126 of 5000 complete in 1.0 sec
#  [-                 4%                  ] 222 of 5000 complete in 1.5 sec
#  [--                6%                  ] 301 of 5000 complete in 2.1 sec
#  [---               8%                  ] 413 of 5000 complete in 2.6 sec
#  [---               9%                  ] 486 of 5000 complete in 3.1 sec
#  [----             11%                  ] 571 of 5000 complete in 3.6 sec
#  [-----            13%                  ] 662 of 5000 complete in 4.1 sec
#  [-----            14%                  ] 721 of 5000 complete in 4.6 sec
#  [------           16%                  ] 803 of 5000 complete in 5.1 sec
#  [------           17%                  ] 895 of 5000 complete in 5.6 sec
#  [-------          19%                  ] 990 of 5000 complete in 6.1 sec
#  [--------         21%                  ] 1075 of 5000 complete in 6.6 sec
#  [--------         23%                  ] 1169 of 5000 complete in 7.1 sec
#  [---------        25%                  ] 1256 of 5000 complete in 7.6 sec
#  [----------       26%                  ] 1338 of 5000 complete in 8.1 sec
#  [----------       28%                  ] 1420 of 5000 complete in 8.6 sec
#  [-----------      30%                  ] 1502 of 5000 complete in 9.2 sec
#  [------------     31%                  ] 1589 of 5000 complete in 9.7 sec
#  [------------     33%                  ] 1668 of 5000 complete in 10.2 sec
#  [-------------    35%                  ] 1759 of 5000 complete in 10.7 sec
#  [--------------   37%                  ] 1854 of 5000 complete in 11.2 sec
#  [--------------   38%                  ] 1939 of 5000 complete in 11.7 sec
#  [---------------  40%                  ] 2029 of 5000 complete in 12.2 sec
#  [---------------- 42%                  ] 2110 of 5000 complete in 12.7 sec
#  [---------------- 44%                  ] 2210 of 5000 complete in 13.2 sec
#  [-----------------45%                  ] 2290 of 5000 complete in 13.7 sec
#  [-----------------47%                  ] 2384 of 5000 complete in 14.2 sec
#  [-----------------49%                  ] 2471 of 5000 complete in 14.7 sec
#  [-----------------51%                  ] 2554 of 5000 complete in 15.2 sec
#  [-----------------52%                  ] 2642 of 5000 complete in 15.7 sec
#  [-----------------54%                  ] 2732 of 5000 complete in 16.2 sec
#  [-----------------56%-                 ] 2821 of 5000 complete in 16.7 sec
#  [-----------------58%--                ] 2920 of 5000 complete in 17.2 sec
#  [-----------------60%--                ] 3013 of 5000 complete in 17.7 sec
#  [-----------------61%---               ] 3096 of 5000 complete in 18.2 sec
#  [-----------------63%----              ] 3191 of 5000 complete in 18.7 sec
#  [-----------------65%----              ] 3267 of 5000 complete in 19.2 sec
#  [-----------------67%-----             ] 3368 of 5000 complete in 19.7 sec
#  [-----------------69%------            ] 3459 of 5000 complete in 20.2 sec
#  [-----------------70%------            ] 3542 of 5000 complete in 20.7 sec
#  [-----------------72%-------           ] 3617 of 5000 complete in 21.3 sec
#  [-----------------74%--------          ] 3701 of 5000 complete in 21.8 sec
#  [-----------------75%--------          ] 3783 of 5000 complete in 22.3 sec
#  [-----------------77%---------         ] 3868 of 5000 complete in 22.8 sec
#  [-----------------79%----------        ] 3964 of 5000 complete in 23.3 sec
#  [-----------------80%----------        ] 4037 of 5000 complete in 23.8 sec
#  [-----------------82%-----------       ] 4104 of 5000 complete in 24.3 sec
#  [-----------------83%-----------       ] 4199 of 5000 complete in 24.8 sec
#  [-----------------85%------------      ] 4271 of 5000 complete in 25.3 sec
#  [-----------------87%-------------     ] 4366 of 5000 complete in 25.8 sec
#  [-----------------89%-------------     ] 4462 of 5000 complete in 26.3 sec
#  [-----------------91%--------------    ] 4557 of 5000 complete in 26.8 sec
#  [-----------------92%---------------   ] 4641 of 5000 complete in 27.3 sec
#  [-----------------94%----------------  ] 4743 of 5000 complete in 27.8 sec
#  [-----------------96%----------------  ] 4837 of 5000 complete in 28.3 sec
#  [-----------------98%----------------- ] 4904 of 5000 complete in 28.8 sec
#  [-----------------99%----------------- ] 4990 of 5000 complete in 29.3 sec
#  [-----------------100%-----------------] 5000 of 5000 complete in 29.4 sec

# %%
## quick plot of regression

def plot_reg(sp, alpha, beta, sigma, xlims, maxlike=False):  
    x = np.arange(xlims[0], xlims[1])
    y_est = eval('{} + {}*x'.format(alpha, beta))
    if maxlike:    
        sp.plot(x, y_est, linewidth=3, linestyle='dashed', color='darkorange', alpha=0.8)
        sp.annotate('alpha: {:.2f}\nbeta:  {:.2f}\nsigma: {:.2f}'.format(alpha, beta, sigma)
                ,xy=(1,0),xycoords='axes fraction',xytext=(-12,6),textcoords='offset points'
                ,color='darkorange',weight='bold',size=12,ha='right',va='bottom')
    else:
        sp.plot(x, y_est, color='#333333', alpha=0.05)

cm_cmap = cm.get_cmap('hsv')
fig, axes1d = plt.subplots(nrows=1, ncols=1, sharex=True, figsize=(12,6))
fig.subplots_adjust(wspace=0.2)
fig.suptitle('Correlation of pre-test and post-test scores - Bayesian')

sp = axes1d
clr = cm_cmap(0)
sp.scatter(x=x,y=y,color=clr,alpha=0.5,edgecolor='#999999')
plot_reg(sp, traces['alpha'].mean(), traces['beta'].mean(), traces['sigma'].mean()
         ,xlims=[x.min(),x.max()],maxlike=True)  

for i in xrange(1000,5000,50):
    point = traces.point(i)
    plot_reg(sp, point['alpha'], point['beta'], point['sigma'], xlims=[x.min(),x.max()])

#plt.show()

# %%
## try unpooled model first for test type

unqvals_tests = np.unique(df.index.get_level_values('test').tolist())
traces_unpooled = {}

for testtype in unqvals_tests:

    x = df.query('test=="{}"'.format(testtype))['staard_score_pre']
    y = df.query('test=="{}"'.format(testtype))['staard_score_post']
    
    with pm.Model() as individual_model:
        
        # intercept prior (variance == sd**2) and slope prior
        alpha = pm.Normal('alpha', mu=0, sd=100**2)
        beta = pm.Normal('beta', mu=0, sd=100**2)
    
        # Model error prior
        eps = pm.Uniform('eps', lower=0, upper=100)
    
        # Linear model
        y_est = alpha + beta * x
    
        # Data likelihood
        likelihood = pm.Normal('event like', mu=y_est, sd=eps, observed=y)
        
        # keep trace
        traces_unpooled[testtype] = pm.sample(2000, step=pm.NUTS(), start=pm.find_MAP(), progressbar=True)
        
        # this is more robust to outliers you need stats model installed
        # with pm.Model() as model_robust:
        #    family = pm.glm.families.T()
# Out:
#  [                  0%                  ] 2 of 2000 complete in 0.6 sec
#  [                  2%                  ] 50 of 2000 complete in 1.1 sec
#  [-                 5%                  ] 104 of 2000 complete in 1.6 sec
#  [---               9%                  ] 188 of 2000 complete in 2.1 sec
#  [-----            13%                  ] 278 of 2000 complete in 2.6 sec
#  [------           18%                  ] 360 of 2000 complete in 3.1 sec
#  [--------         22%                  ] 441 of 2000 complete in 3.6 sec
#  [----------       26%                  ] 532 of 2000 complete in 4.1 sec
#  [-----------      31%                  ] 627 of 2000 complete in 4.6 sec
#  [-------------    35%                  ] 706 of 2000 complete in 5.1 sec
#  [---------------  39%                  ] 790 of 2000 complete in 5.7 sec
#  [---------------- 44%                  ] 880 of 2000 complete in 6.2 sec
#  [-----------------48%                  ] 975 of 2000 complete in 6.7 sec
#  [-----------------53%                  ] 1065 of 2000 complete in 7.2 sec
#  [-----------------58%--                ] 1162 of 2000 complete in 7.7 sec
#  [-----------------62%---               ] 1259 of 2000 complete in 8.2 sec
#  [-----------------66%-----             ] 1337 of 2000 complete in 8.7 sec
#  [-----------------72%-------           ] 1447 of 2000 complete in 9.2 sec
#  [-----------------77%---------         ] 1540 of 2000 complete in 9.7 sec
#  [-----------------81%-----------       ] 1637 of 2000 complete in 10.2 sec
#  [-----------------86%------------      ] 1733 of 2000 complete in 10.7 sec
#  [-----------------91%--------------    ] 1824 of 2000 complete in 11.2 sec
#  [-----------------96%----------------  ] 1922 of 2000 complete in 11.7 sec
#  [-----------------100%-----------------] 2000 of 2000 complete in 12.2 sec
#  [                  2%                  ] 46 of 2000 complete in 0.5 sec
#  [--                5%                  ] 109 of 2000 complete in 1.0 sec
#  [---               9%                  ] 192 of 2000 complete in 1.5 sec
#  [-----            13%                  ] 264 of 2000 complete in 2.0 sec
#  [------           16%                  ] 327 of 2000 complete in 2.5 sec
#  [-------          20%                  ] 417 of 2000 complete in 3.0 sec
#  [---------        25%                  ] 502 of 2000 complete in 3.5 sec
#  [-----------      29%                  ] 596 of 2000 complete in 4.0 sec
#  [-------------    34%                  ] 690 of 2000 complete in 4.5 sec
#  [---------------  39%                  ] 797 of 2000 complete in 5.0 sec
#  [---------------- 44%                  ] 889 of 2000 complete in 5.5 sec
#  [-----------------48%                  ] 966 of 2000 complete in 6.0 sec
#  [-----------------52%                  ] 1048 of 2000 complete in 6.6 sec
#  [-----------------56%-                 ] 1122 of 2000 complete in 7.1 sec
#  [-----------------59%--                ] 1198 of 2000 complete in 7.6 sec
#  [-----------------64%----              ] 1285 of 2000 complete in 8.1 sec
#  [-----------------68%------            ] 1370 of 2000 complete in 8.6 sec
#  [-----------------72%-------           ] 1454 of 2000 complete in 9.1 sec
#  [-----------------75%--------          ] 1518 of 2000 complete in 9.6 sec
#  [-----------------79%----------        ] 1588 of 2000 complete in 10.1 sec
#  [-----------------83%-----------       ] 1676 of 2000 complete in 10.6 sec
#  [-----------------87%-------------     ] 1753 of 2000 complete in 11.1 sec
#  [-----------------91%--------------    ] 1833 of 2000 complete in 11.6 sec
#  [-----------------94%---------------   ] 1883 of 2000 complete in 12.1 sec
#  [-----------------97%----------------- ] 1954 of 2000 complete in 12.6 sec
#  [-----------------100%-----------------] 2000 of 2000 complete in 13.1 sec

# %%
for testtype in unqvals_tests:
    print('Estimates for: {}'.format(testtype))
    tp = pm.traceplot(traces_unpooled[testtype])
    tp.show()
# Out:
# Estimates for: reading
# Estimates for: spelling

# %%
def plot_breg(formula, x_min, x_max):  
    x = np.arange(x_min, x_max)
    y_est = eval(formula)
    plt.plot(x, y_est)  
    
plt.scatter(x,y)
plot_breg('23 + 0.79*x', x.min(), x.max())
plt.show()

# %% [markdown]
# ---
#
# _copyleft_ **Open Data Science Ireland Meetup Group 2014**
# <a href='http://www.meetup.com/opendatascienceireland/'>ODSI@meetup.com</a>
