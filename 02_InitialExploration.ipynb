# %% [markdown]
# <div style="float:right"><img src='files/assets/img/Suas_Logo_Header.png'></img></div>
#
# ## Suas Educational Development - Literacy Intervention Investigation
#
# # 02 Initial Exploration
#
# Contact: Adelaide Nic Chartaigh [adelaide@suas.ie]("mailto:adelaide@suas.ie")
# Author: Jonathan Sedar [jon.sedar@applied.ai]("mailto:jon.sedar@applied.ai")
# Date: Spring / Summer 2014
#
# #Contents
#
# + [Setup](#Setup)
# + [Import Data](#Import-Data)
# + [Frequentist Regression](#Frequentist-Regression)
# + [Bayesian Regression](#Bayesian-Regression)
#     + [Unpooled Models](#Unpooled-Models)
#     + [Hierarchical Models](#Hierarchical-Models)

# %% [markdown]
# # Setup

# %%
## Interactive magics
# %matplotlib inline
# %qtconsole --colors=linux --ConsoleWidget.font_size=10 --ConsoleWidget.font_family='Consolas'

# %%
## Libraries and global options
from __future__ import division, print_function
import os
import sys
import re
import string
import time

import pandas as pd
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
from matplotlib import cm
import sqlite3
from sklearn import linear_model
import pymc as pm

#from sklearn.covariance import MinCovDet
#from sklearn.preprocessing import Normalizer
#from collections import OrderedDict

# Set some default pandas and plotting formatting
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 1000)
pd.set_option('display.width', 1000)
pd.set_option('display.mpl_style', 'default')
pd.set_option('display.notebook_repr_html', True)
pd.set_option('display.expand_frame_repr', True)
pd.set_option('display.precision', 5)
pd.set_option('display.max_colwidth', 50)

plt.rcParams['figure.figsize'] = 6, 6

# handle temporary deprecation warning in pandas for describe()
import warnings
warnings.simplefilter("ignore", DeprecationWarning)
warnings.simplefilter("ignore", UserWarning)
warnings.simplefilter("ignore", FutureWarning)
warnings.simplefilter("ignore", RuntimeWarning)

remove_punct_map = dict.fromkeys(map(ord, string.punctuation))

# %% [markdown]
# # Import Data

# %%
## Read cleaned dataset back from db
cnx_sql3 = sqlite3.connect('data/SUAS_data_master_v001_tcc_cleaned.db')
cnx_sql3.text_factory = str
df = pd.read_sql('select * from df_piv', cnx_sql3, index_col=['code','schoolid','gender','test','testtype']
                 , parse_dates=['date_pre','date_post'])
cnx_sql3.close()

print(df.shape)
df.head()
# Out:
# (235, 8)
#                                                                date_pre  date_post  age_pre  age_post  raw_score_pre  raw_score_post  staard_score_pre  staard_score_post
# code         schoolid  gender test    testtype
# NDMS_ARAWm01 NDMS_ARAW m      reading acceleread_accelewrite 2013-10-21 2013-11-29     9.22      9.33             27              31                85                 89
# NDMS_ARAWm02 NDMS_ARAW m      reading acceleread_accelewrite 2013-10-21 2013-11-29     9.98     10.08             37              40                97                 94
# NDMS_ARAWm03 NDMS_ARAW m      reading acceleread_accelewrite 2013-10-21 2013-11-29    10.05     10.16             27              26                80                 76
# NDMS_ARAWm04 NDMS_ARAW m      reading acceleread_accelewrite 2013-10-21 2013-11-29    10.16     10.26             34              36                91                 89
# NDMS_ARAWm05 NDMS_ARAW m      reading acceleread_accelewrite 2013-10-21 2013-11-29    10.30     10.41             22              25                71                 74

# %% [markdown]
# ### Calc some deltas for convenience

# %%
df['date_delta'] = df['date_post'] - df['date_pre']
df['age_delta'] = df['age_post'] - df['age_pre']
df['raw_score_delta'] = df['raw_score_post'] - df['raw_score_pre']
df['staard_score_delta'] = df['staard_score_post'] - df['staard_score_pre']

df = df.sort_index(axis=1)
df.head()
# Out:
#                                                               age_delta  age_post  age_pre  date_delta  date_post   date_pre  raw_score_delta  raw_score_post  raw_score_pre  staard_score_delta  staard_score_post  staard_score_pre
# code         schoolid  gender test    testtype
# NDMS_ARAWm01 NDMS_ARAW m      reading acceleread_accelewrite       0.11      9.33     9.22     39 days 2013-11-29 2013-10-21                4              31             27                   4                 89                85
# NDMS_ARAWm02 NDMS_ARAW m      reading acceleread_accelewrite       0.10     10.08     9.98     39 days 2013-11-29 2013-10-21                3              40             37                  -3                 94                97
# NDMS_ARAWm03 NDMS_ARAW m      reading acceleread_accelewrite       0.11     10.16    10.05     39 days 2013-11-29 2013-10-21               -1              26             27                  -4                 76                80
# NDMS_ARAWm04 NDMS_ARAW m      reading acceleread_accelewrite       0.10     10.26    10.16     39 days 2013-11-29 2013-10-21                2              36             34                  -2                 89                91
# NDMS_ARAWm05 NDMS_ARAW m      reading acceleread_accelewrite       0.11     10.41    10.30     39 days 2013-11-29 2013-10-21                3              25             22                   3                 74                71

# %% [markdown]
# ---

# %% [markdown]
# # Frequentist Regression

# %% [markdown]
# ### Entire set

# %%
## scores pre vs post for all

x = df['staard_score_pre']
y = df['staard_score_post']

cm_cmap = cm.get_cmap('hsv')
fig, axes1d = plt.subplots(nrows=1, ncols=1, sharex=True, figsize=(8,8))
fig.subplots_adjust(wspace=0.2)
fig.suptitle('Correlation of pre-test and post-test scores')

sp = axes1d
clr = cm_cmap(0.6)
sp.scatter(x=x,y=y,color=clr,alpha=0.6,edgecolor='#999999')

# fit and plot a new linear model
regr = linear_model.LinearRegression()
regr.fit(pd.DataFrame(x),pd.DataFrame(y))
x_prime = np.linspace(x.min(),x.max(),num=10)[:,np.newaxis]
y_hat = regr.predict(x_prime)
sp.plot(x_prime,y_hat,linewidth=2,linestyle='dashed',color='green',alpha=0.8)

ss_res = regr.residues_[0]
ss_tot = np.sum((y - np.mean(y))**2)
rsq = 1 - (ss_res/ss_tot)

sp.annotate('R^2:  {:.2f}\nCoef: {:.2f}\nIntr: {:.2f}'.format(rsq,regr.coef_[0][0],regr.intercept_[0])
                ,xy=(1,0),xycoords='axes fraction',xytext=(-12,6),textcoords='offset points'
                ,color='green',weight='bold',size=12,ha='right',va='bottom')
sp.set_ylabel('Post-test Score')
sp.set_xlabel('Pre-test Score')
sp.axes.grid(True,linestyle='-',color='lightgrey')

plt.subplots_adjust(top=0.95)
plt.show()

# %%
## scores pre vs post for test type

## TODO

# %% [markdown]
# ---

# %% [markdown]
# # Bayesian Regression

# %% [markdown]
# ## Unpooled Models

# %% [markdown]
# Simple linear regression
#
# ### Entire set

# %%
## try unpooled model first for all

x = df['staard_score_pre']
y = df['staard_score_post']

with pm.Model() as individual_model:

    # priors for intercept, slope and precision - all uninformative
    alpha = pm.Normal('alpha', mu=0, sd=100**2)
    beta = pm.Normal('beta', mu=0, sd=100**2)
    sigma = pm.Uniform('sigma', lower=0, upper=100)

    # Linear model
    y_est = alpha + beta * x

    # Data likelihood
    likelihood = pm.Normal('event like', mu=y_est, sd=sigma, observed=y)

    # keep trace
#  [-----------------78%---------         ] 7815 of 10000 complete in 48.5 sec
#  [-----------------79%----------        ] 7908 of 10000 complete in 49.0 sec
#  [-----------------79%----------        ] 7985 of 10000 complete in 49.6 sec
#  [-----------------80%----------        ] 8074 of 10000 complete in 50.1 sec
#  [-----------------81%-----------       ] 8160 of 10000 complete in 50.6 sec
#  [-----------------82%-----------       ] 8251 of 10000 complete in 51.1 sec
#  [-----------------83%-----------       ] 8328 of 10000 complete in 51.6 sec
#  [-----------------84%-----------       ] 8418 of 10000 complete in 52.1 sec
#  [-----------------84%------------      ] 8497 of 10000 complete in 52.6 sec
#  [-----------------85%------------      ] 8595 of 10000 complete in 53.1 sec
#  [-----------------86%------------      ] 8682 of 10000 complete in 53.6 sec
#  [-----------------87%-------------     ] 8768 of 10000 complete in 54.1 sec
#  [-----------------88%-------------     ] 8848 of 10000 complete in 54.6 sec
#  [-----------------89%--------------    ] 8953 of 10000 complete in 55.1 sec
#  [-----------------90%--------------    ] 9040 of 10000 complete in 55.6 sec
#  [-----------------91%--------------    ] 9126 of 10000 complete in 56.1 sec
#  [-----------------92%---------------   ] 9221 of 10000 complete in 56.6 sec
#  [-----------------93%---------------   ] 9317 of 10000 complete in 57.1 sec
#  [-----------------94%---------------   ] 9417 of 10000 complete in 57.6 sec
#  [-----------------94%----------------  ] 9498 of 10000 complete in 58.2 sec
#  [-----------------95%----------------  ] 9586 of 10000 complete in 58.7 sec
#  [-----------------96%----------------  ] 9676 of 10000 complete in 59.2 sec
#  [-----------------97%----------------- ] 9762 of 10000 complete in 59.7 sec
#  [-----------------98%----------------- ] 9842 of 10000 complete in 60.2 sec
#  [-----------------99%----------------- ] 9929 of 10000 complete in 60.7 sec
#  [-----------------100%-----------------] 10000 of 10000 complete in 61.2 sec

# %% [markdown]
# ### Plot regression

# %%
## quick plot of regression (all)

def plot_reg(sp, alpha, beta, sigma, xlims, maxlike=False):  
    x = np.arange(xlims[0], xlims[1])
    y_est = eval('{} + {}*x'.format(alpha, beta))
    if maxlike:    
        sp.plot(x, y_est, linewidth=3, linestyle='dashed', color='#00F5FF', alpha=0.8)
        sp.annotate('{}\nalpha: {:.2f}\nbeta:  {:.2f}\nsigma: {:.2f}'.format(
                    'individual',alpha, beta, sigma)
                ,xy=(1,0),xycoords='axes fraction',xytext=(-12,6),textcoords='offset points'
                ,color='#05B9B0',weight='bold',size=12,ha='right',va='bottom') # #FF5800
    else:
        sp.plot(x, y_est, color='#006266', alpha=0.04)

cm_cmap = cm.get_cmap('hsv')
fig, axes1d = plt.subplots(nrows=1, ncols=1, sharex=True, figsize=(8,8))
fig.subplots_adjust(wspace=0.2)
fig.suptitle('Correlation of pre-test and post-test scores - Bayesian')

sp = axes1d
clr = cm_cmap(0.6)
sp.scatter(x=x,y=y,color=clr,alpha=0.6,edgecolor='#999999')

for i in xrange(1000,5000,10):
    point = traces.point(i)
    plot_reg(sp, point['alpha'], point['beta'], point['sigma'], xlims=[x.min(),x.max()])

plot_reg(sp, traces['alpha'].mean(), traces['beta'].mean(), traces['sigma'].mean()
     ,xlims=[x.min(),x.max()],maxlike=True)  

#plt.show()

# %% [markdown]
# ### Testtype

# %%
## unpooled model for test type

unqvals = np.unique(df.index.get_level_values('test').tolist())
traces_unpooled = {}
max_iter_unpooled = 10000

for testtype in unqvals_tests:

    x = df.query('test=="{}"'.format(testtype))['staard_score_pre']
    y = df.query('test=="{}"'.format(testtype))['staard_score_post']
    
    with pm.Model() as individual_model:

        # priors for intercept, slope and precision - all uninformative
        alpha = pm.Normal('alpha', mu=0, sd=100**2)
        beta = pm.Normal('beta', mu=0, sd=100**2)
        sigma = pm.Uniform('sigma', lower=0, upper=100)

        # Linear model
        y_est = alpha + beta * x

        # Data likelihood
        likelihood = pm.Normal('likelihood', mu=y_est, sd=sigma, observed=y)

        # keep trace
        traces_unpooled[testtype] = pm.sample(max_iter_unpooled, step=pm.NUTS()
                                              ,start=pm.find_MAP() ,progressbar=True)
# Out:
#  [                  0%                  ] 37 of 10000 complete in 0.5 sec
#  [                  0%                  ] 98 of 10000 complete in 1.0 sec
#  [                  1%                  ] 180 of 10000 complete in 1.5 sec
#  [                  2%                  ] 255 of 10000 complete in 2.0 sec
#  [-                 3%                  ] 344 of 10000 complete in 2.5 sec
#  [-                 4%                  ] 434 of 10000 complete in 3.0 sec
#  [-                 5%                  ] 520 of 10000 complete in 3.6 sec
#  [--                6%                  ] 614 of 10000 complete in 4.1 sec
#  [--                7%                  ] 714 of 10000 complete in 4.6 sec
#  [---               8%                  ] 804 of 10000 complete in 5.1 sec
#  [---               9%                  ] 906 of 10000 complete in 5.6 sec
#  [---              10%                  ] 1008 of 10000 complete in 6.1 sec
#  [----             10%                  ] 1096 of 10000 complete in 6.6 sec
#  [----             11%                  ] 1174 of 10000 complete in 7.1 sec
#  [----             12%                  ] 1271 of 10000 complete in 7.6 sec
#  [-----            13%                  ] 1360 of 10000 complete in 8.1 sec
#  [-----            14%                  ] 1450 of 10000 complete in 8.6 sec
#  [-----            15%                  ] 1536 of 10000 complete in 9.1 sec
#  [------           16%                  ] 1630 of 10000 complete in 9.6 sec
#  [------           17%                  ] 1726 of 10000 complete in 10.1 sec
#  [------           17%                  ] 1799 of 10000 complete in 10.6 sec
#  [-------          19%                  ] 1903 of 10000 complete in 11.1 sec
#  [-------          19%                  ] 1997 of 10000 complete in 11.6 sec
#  [-------          20%                  ] 2058 of 10000 complete in 12.1 sec
#  [--------         21%                  ] 2137 of 10000 complete in 12.6 sec
#  [--------         22%                  ] 2204 of 10000 complete in 13.1 sec
#  [--------         22%                  ] 2290 of 10000 complete in 13.7 sec
#  [---------        23%                  ] 2382 of 10000 complete in 14.2 sec
#  [---------        24%                  ] 2474 of 10000 complete in 14.7 sec
#  [---------        25%                  ] 2569 of 10000 complete in 15.2 sec
#  [----------       26%                  ] 2665 of 10000 complete in 15.7 sec
#  [----------       27%                  ] 2749 of 10000 complete in 16.2 sec
#  [----------       28%                  ] 2841 of 10000 complete in 16.7 sec
#  [-----------      28%                  ] 2898 of 10000 complete in 17.2 sec
#  [-----------      29%                  ] 2972 of 10000 complete in 17.7 sec
#  [-----------      30%                  ] 3058 of 10000 complete in 18.2 sec
#  [-----------      31%                  ] 3137 of 10000 complete in 18.7 sec
#  [-----------------76%---------         ] 7694 of 10000 complete in 55.4 sec
#  [-----------------77%---------         ] 7776 of 10000 complete in 55.9 sec
#  [-----------------78%---------         ] 7844 of 10000 complete in 56.4 sec
#  [-----------------79%----------        ] 7916 of 10000 complete in 56.9 sec
#  [-----------------79%----------        ] 7980 of 10000 complete in 57.4 sec
#  [-----------------80%----------        ] 8067 of 10000 complete in 57.9 sec
#  [-----------------81%----------        ] 8141 of 10000 complete in 58.4 sec
#  [-----------------82%-----------       ] 8223 of 10000 complete in 59.0 sec
#  [-----------------83%-----------       ] 8302 of 10000 complete in 59.5 sec
#  [-----------------83%-----------       ] 8377 of 10000 complete in 60.0 sec
#  [-----------------84%------------      ] 8453 of 10000 complete in 60.5 sec
#  [-----------------85%------------      ] 8519 of 10000 complete in 61.0 sec
#  [-----------------85%------------      ] 8591 of 10000 complete in 61.5 sec
#  [-----------------86%------------      ] 8651 of 10000 complete in 62.0 sec
#  [-----------------86%------------      ] 8680 of 10000 complete in 62.5 sec
#  [-----------------87%-------------     ] 8709 of 10000 complete in 63.0 sec
#  [-----------------87%-------------     ] 8733 of 10000 complete in 63.5 sec
#  [-----------------87%-------------     ] 8755 of 10000 complete in 64.0 sec
#  [-----------------87%-------------     ] 8780 of 10000 complete in 64.5 sec
#  [-----------------88%-------------     ] 8813 of 10000 complete in 65.0 sec
#  [-----------------88%-------------     ] 8849 of 10000 complete in 65.6 sec
#  [-----------------88%-------------     ] 8899 of 10000 complete in 66.1 sec
#  [-----------------89%--------------    ] 8960 of 10000 complete in 66.6 sec
#  [-----------------90%--------------    ] 9025 of 10000 complete in 67.1 sec
#  [-----------------90%--------------    ] 9091 of 10000 complete in 67.6 sec
#  [-----------------91%--------------    ] 9177 of 10000 complete in 68.1 sec
#  [-----------------92%---------------   ] 9252 of 10000 complete in 68.6 sec
#  [-----------------93%---------------   ] 9323 of 10000 complete in 69.1 sec
#  [-----------------94%---------------   ] 9424 of 10000 complete in 69.7 sec
#  [-----------------95%----------------  ] 9508 of 10000 complete in 70.2 sec
#  [-----------------96%----------------  ] 9601 of 10000 complete in 70.7 sec
#  [-----------------97%----------------  ] 9704 of 10000 complete in 71.2 sec
#  [-----------------97%----------------- ] 9786 of 10000 complete in 71.7 sec
#  [-----------------98%----------------- ] 9858 of 10000 complete in 72.2 sec
#  [-----------------99%----------------- ] 9940 of 10000 complete in 72.7 sec
#  [-----------------100%-----------------] 10000 of 10000 complete in 73.0 sec

# %%
burn_in_unpooled = 2000

for testtype in unqvals:
    print('Estimates for: {}'.format(testtype))
    pm.traceplot(traces_unpooled[testtype],figsize=(18,2*3))
# Out:
# Estimates for: reading
# Estimates for: spelling

# %% [markdown]
# ## Hierarchical Models

# %% [markdown]
# Hierarchical linear regression for test type
#
# ### Testtype

# %%
## run for test types

# unqvals = np.unique(df.index.get_level_values('test').tolist())
idx_size = unqvals_tests.shape[0]
unqvals_translator = {v:k for k,v in enumerate(unqvals_tests)}
idxs = [unqvals_translator[v] for v in df.index.get_level_values('test').tolist()]

x = df['staard_score_pre']
y = df['staard_score_post']

max_iter = 200000

with pm.Model() as hierarchical_model:

    # hyperpriors for group nodes, all uninformative
    alpha_mu = pm.Normal('alpha_mu', mu=0., sd=100**2)
    alpha_sigma = pm.Uniform('alpha_sigma', lower=0, upper=100)
    beta_mu = pm.Normal('beta_mu', mu=0., sd=100**2)
    beta_sigma = pm.Uniform('beta_sigma', lower=0, upper=100)
    
    # Intercept for each testtype, distributed around group mean mu_a
    # Above we just set mu and sd to a fixed value while here we
    # plug in a common group distribution for all a and b (which are
    # vectors of length n_testtype).
       
    # priors for alpha, beta and model error, uninformative  
    alpha = pm.Normal('alpha', mu=alpha_mu, sd=alpha_sigma, shape=idx_size)
    beta = pm.Normal('beta', mu=beta_mu, sd=beta_sigma, shape=idx_size)
    sigma = pm.Uniform('sigma', lower=0, upper=100)

    # hierarchical linear model
    y_est = alpha[idxs] + beta[idxs] * x

    # Data likelihood
    likelihood = pm.Normal('likelihood', mu=y_est, sd=sigma, observed=y)

    # keep trace
    traces_hierarchical = pm.sample(max_iter, step=pm.Metropolis()
                                   ,start=pm.find_MAP(), progressbar=True)
# Out:
#  [                  0%                  ] 725 of 200000 complete in 0.5 sec
#  [                  0%                  ] 1496 of 200000 complete in 1.0 sec
#  [                  1%                  ] 2265 of 200000 complete in 1.5 sec
#  [                  1%                  ] 3020 of 200000 complete in 2.0 sec
#  [                  1%                  ] 3789 of 200000 complete in 2.5 sec
#  [                  2%                  ] 4558 of 200000 complete in 3.0 sec
#  [-                 2%                  ] 5322 of 200000 complete in 3.5 sec
#  [-                 3%                  ] 6115 of 200000 complete in 4.0 sec
#  [-                 3%                  ] 6877 of 200000 complete in 4.5 sec
#  [-                 3%                  ] 7656 of 200000 complete in 5.0 sec
#  [-                 4%                  ] 8301 of 200000 complete in 5.5 sec
#  [-                 4%                  ] 9004 of 200000 complete in 6.0 sec
#  [-                 4%                  ] 9713 of 200000 complete in 6.5 sec
#  [-                 5%                  ] 10455 of 200000 complete in 7.0 sec
#  [--                5%                  ] 11182 of 200000 complete in 7.5 sec
#  [--                5%                  ] 11932 of 200000 complete in 8.0 sec
#  [--                6%                  ] 12691 of 200000 complete in 8.5 sec
#  [--                6%                  ] 13459 of 200000 complete in 9.0 sec
#  [--                7%                  ] 14214 of 200000 complete in 9.5 sec
#  [--                7%                  ] 15001 of 200000 complete in 10.0 sec
#  [--                7%                  ] 15746 of 200000 complete in 10.5 sec
#  [---               8%                  ] 16410 of 200000 complete in 11.0 sec
#  [---               8%                  ] 17135 of 200000 complete in 11.5 sec
#  [---               8%                  ] 17888 of 200000 complete in 12.0 sec
#  [---               9%                  ] 18588 of 200000 complete in 12.5 sec
#  [---               9%                  ] 19356 of 200000 complete in 13.0 sec
#  [---              10%                  ] 20118 of 200000 complete in 13.5 sec
#  [---              10%                  ] 20769 of 200000 complete in 14.0 sec
#  [----             10%                  ] 21512 of 200000 complete in 14.5 sec
#  [----             11%                  ] 22100 of 200000 complete in 15.0 sec
#  [----             11%                  ] 22764 of 200000 complete in 15.5 sec
#  [----             11%                  ] 23484 of 200000 complete in 16.0 sec
#  [----             12%                  ] 24261 of 200000 complete in 16.5 sec
#  [----             12%                  ] 25009 of 200000 complete in 17.0 sec
#  [-----------------98%----------------- ] 197401 of 200000 complete in 135.6 sec
#  [-----------------99%----------------- ] 198136 of 200000 complete in 136.1 sec
#  [-----------------99%----------------- ] 198841 of 200000 complete in 136.6 sec
#  [-----------------99%----------------- ] 199599 of 200000 complete in 137.1 sec
#  [-----------------100%-----------------] 200000 of 200000 complete in 137.4 sec

# %%
## quick plot of parameters
burn_in = 50000
with pm.Model() as hierarchical_model:
    pm.traceplot(traces_hierarchical,figsize=(18,2*7))

# %% [markdown]
# ### Plot comparison of hierarchical vs unpooled

# %%
def plot_reg_hier(sp, alpha, beta, sigma, xlims, maxlike=False):  
    x = np.arange(xlims[0], xlims[1])
    y_est = eval('{} + {}*x'.format(alpha, beta))
    if maxlike:    
        sp.plot(x, y_est, linewidth=3, linestyle='dashed', color='#FF7538', alpha=0.8)
        sp.annotate('{}\nalpha: {:.2f}\nbeta:  {:.2f}\nsigma: {:.2f}'.format(
                    'hierarchical',alpha, beta, sigma)
                ,xy=(0,1),xycoords='axes fraction',xytext=(12,-6),textcoords='offset points'
                ,color='#FF7538',weight='bold',size=12,ha='left',va='top')
    else:
        sp.plot(x, y_est, color='#661f00', alpha=0.03)


fig, axes1d = plt.subplots(nrows=1, ncols=2, sharex=True, sharey=True, figsize=(18,8))
fig.subplots_adjust(wspace=0.2)
fig.suptitle('Correlation of pre-test and post-test scores - Bayesian Hierarchical Regression')
cm_cmap = cm.get_cmap('hsv')

for j, (sp, testtype) in enumerate(zip(axes1d,unqvals)):

    x = df.query('test=="{}"'.format(testtype))['staard_score_pre']
    y = df.query('test=="{}"'.format(testtype))['staard_score_post']
    clr = cm_cmap(j/len(unqvals))

    # points
    sp.scatter(x=x,y=y,color=clr,alpha=0.6,edgecolor='#999999')
    sp.annotate(testtype,xy=(0.5,1),xycoords='axes fraction',size=12,ha='center'
                ,xytext=(0,6),textcoords='offset points')

    # unpooled
    for i in np.vectorize(lambda x: int(round(x,0)))\
                    (np.linspace(burn_in_unpooled,max_iter_unpooled,500,endpoint=False)):
        traces = traces_unpooled[testtype]
        point = traces.point(i)
        plot_reg(sp, point['alpha'], point['beta'], point['sigma'], xlims=[x.min(),x.max()])

    plot_reg(sp, traces['alpha'].mean(),traces['beta'].mean(),traces['sigma'].mean()
                    ,xlims=[x.min(),x.max()],maxlike=True)  

    
    # hierarchical
    for i in np.vectorize(lambda x: int(round(x,0)))\
                    (np.linspace(burn_in,max_iter,500,endpoint=False)):
        alpha = traces_hierarchical['alpha'][i][j]
        beta = traces_hierarchical['beta'][i][j]
        sigma = traces_hierarchical['sigma'][i]    # TODO: redundant in this call, refactor
        plot_reg_hier(sp, alpha, beta, sigma, xlims=[x.min(),x.max()])

    plot_reg_hier(sp, traces_hierarchical['alpha'][:,j].mean()
                    ,traces_hierarchical['beta'][:,j].mean()
                    ,traces_hierarchical['sigma'].mean()
                    ,xlims=[x.min(),x.max()],maxlike=True)

# %% [markdown]
# ---
#
# _copyleft_ **Open Data Science Ireland Meetup Group 2014**
# <a href='http://www.meetup.com/opendatascienceireland/'>ODSI@meetup.com</a>
